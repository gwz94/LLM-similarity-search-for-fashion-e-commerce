# %%
import pandas as pd
import numpy as np
from itertools import chain

import json

# %% [markdown]
# # Purpose of this notebook
#
# - This notebook is for data exploration, EDA, and strategy planning.

# %% [markdown]
# # Load Data

# %%
data = []
with open("../backend/app/raw_data/meta_amazon_fashion.jsonl", "r") as f:
    for line in f:
        item = json.loads(line)
        data.append(item)

df_amazon_fashion = pd.DataFrame(data)

# %% [markdown]
# # Dataset basic info

# %%
df_amazon_fashion.columns
# Out:
# Index(['main_category', 'title', 'average_rating', 'rating_number', 'features',
#        'description', 'price', 'images', 'videos', 'store', 'categories',
#        'details', 'parent_asin', 'bought_together'],
#       dtype='object')

# %%
df_amazon_fashion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826108 entries, 0 to 826107
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   main_category    826108 non-null  object
#  1   title            826108 non-null  object
#  2   average_rating   826108 non-null  float64
#  3   rating_number    826108 non-null  int64
#  4   features         826108 non-null  object
#  5   description      826108 non-null  object
#  6   price            50249 non-null   float64
#  7   images           826108 non-null  object
#  8   videos           826108 non-null  object
#  9   store            799270 non-null  object
#  10  categories       826108 non-null  object
#  11  details          826108 non-null  object
#  12  parent_asin      826108 non-null  object
#  13  bought_together  0 non-null       object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 88.2+ MB

# %%
df_amazon_fashion["price"].isna().sum()
print(f"Number of items without price: {df_amazon_fashion['price'].isna().sum()}")

df_amazon_fashion["store"].isna().sum()
print(f"Number of items without store: {df_amazon_fashion['store'].isna().sum()}")
# Out:
# Number of items without price: 775859
# Number of items without store: 26838

# %%
df_amazon_fashion.describe()
# Out:
#        average_rating  rating_number         price
# count   826108.000000  826108.000000  50249.000000
# mean         3.910660      17.942204     40.795929
# std          0.982282     221.792730    154.089435
# min          1.000000       1.000000      0.010000
# 25%          3.400000       2.000000     11.790000
# 50%          4.000000       4.000000     19.890000
# 75%          4.700000      10.000000     34.990000
# max          5.000000   46299.000000  13000.000000

# %%
df_amazon_fashion.head()
# Out:
#     main_category                                              title  \
# 0  AMAZON FASHION  YUEDGE 5 Pairs Men's Moisture Control Cushione...
# 1  AMAZON FASHION  DouBCQ Women's Palazzo Lounge Wide Leg Casual ...
# 2  AMAZON FASHION  Pastel by Vivienne Honey Vanilla Girls' Trapez...
# 3  AMAZON FASHION                                   Mento Streamtail
# 4  AMAZON FASHION  RONNOX Women's 3-Pairs Bright Colored Calf Com...
#
#    average_rating  rating_number  \
# 0             4.6             16
# 1             4.1              7
# 2             4.3             11
# 3             2.0              1
# 4             4.3           3032
#
#                                             features  \
# 0                                                 []
# 1                 [Drawstring closure, Machine Wash]
# 2                   [Zipper closure, Hand Wash Only]
# 3  [Thermoplastic Rubber sole, High Density Premi...
# 4  [Pull On closure, Size Guide: "S" fits calf 10...
#
#                                          description  price  \
# 0                                                 []    NaN
# 1                                                 []    NaN
# 2                                                 []    NaN
# 3  [Slip on the Women's Mento and you're ready to...  29.81
# 4  [Ronnox Calf Sleeves - Allowing Your Body to P...  17.99
#
#                                               images  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  [{'thumb': 'https://m.media-amazon.com/images/...
# 2  [{'thumb': 'https://m.media-amazon.com/images/...
# 3  [{'thumb': 'https://m.media-amazon.com/images/...
# 4  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos               store  \
# 0                                                 []            GiveGift
# 1                                                 []              DouBCQ
# 2                                                 []  Pastel by Vivienne
# 3                                                 []          Guy Harvey
# 4  [{'title': 'HONEST Review: RONNOX Women's 3-Pa...              RONNOX
#
#   categories                                            details parent_asin  \
# 0         []  {'Package Dimensions': '10.31 x 8.5 x 1.73 inc...  B08BHN9PK5
# 1         []  {'Package Dimensions': '15 x 10.2 x 0.4 inches...  B08R39MRDW
# 2         []  {'Is Discontinued By Manufacturer': 'No', 'Pac...  B077KJHCJ4
# 3         []  {'Package Dimensions': '11.22 x 4.72 x 4.33 in...  B0811M2JG9
# 4         []  {'Is Discontinued By Manufacturer': 'No', 'Pac...  B07SB2892S
#
#   bought_together
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None

# %% [markdown]
# # Dataset preprocessing

# %%
# Handle missing values or values with only space
df_amazon_fashion = df_amazon_fashion.applymap(
    lambda x: np.nan               # turn into NaN
    if (
        (isinstance(x, list) and len(x) == 0)
        or (isinstance(x, str) and x.strip() == "")
    )
    else x
)
df_amazon_fashion.info()
# Out:
# /var/folders/1_/cl4bz3j57jq24gm92byzkmbw0000gn/T/ipykernel_6242/2224551997.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_amazon_fashion = df_amazon_fashion.applymap(
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826108 entries, 0 to 826107
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   main_category    826108 non-null  object
#  1   title            826050 non-null  object
#  2   average_rating   826108 non-null  float64
#  3   rating_number    826108 non-null  int64
#  4   features         463074 non-null  object
#  5   description      59289 non-null   object
#  6   price            50249 non-null   float64
#  7   images           826107 non-null  object
#  8   videos           52107 non-null   object
#  9   store            799267 non-null  object
#  10  categories       0 non-null       float64
#  11  details          826108 non-null  object
#  12  parent_asin      826108 non-null  object
#  13  bought_together  0 non-null       object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 88.2+ MB

# %%
# Duplicated products check
dupes = df_amazon_fashion[df_amazon_fashion["title"].duplicated(keep=False)]
dupes.sort_values(["title", "price"])
# Out:
#          main_category                                              title  \
# 24011   AMAZON FASHION  " Colors of Love" Iridescent Glitter Opal with...
# 426278  AMAZON FASHION  " Colors of Love" Iridescent Glitter Opal with...
# 507984  AMAZON FASHION  " Colors of Love" Iridescent Glitter Opal with...
# 72762   AMAZON FASHION  " Pretty Bold" Geometric Layered with Gold or ...
# 93351   AMAZON FASHION  " Pretty Bold" Geometric Layered with Gold or ...
# ...                ...                                                ...
# 137831  AMAZON FASHION                                                NaN
# 137835  AMAZON FASHION                                                NaN
# 137837  AMAZON FASHION                                                NaN
# 137839  AMAZON FASHION                                                NaN
# 528253  AMAZON FASHION                                                NaN
#
#         average_rating  rating_number                              features  \
# 24011              5.0              1                                   NaN
# 426278             3.9              4                                   NaN
# 507984             5.0              1                                   NaN
# 72762              4.4              9                                   NaN
# 93351              4.3              9                                   NaN
# ...                ...            ...                                   ...
# 137831             5.0              1                                   NaN
# 137835             2.6              3                      [Hand Wash Only]
# 137837             3.0              4  [Microfiber,flannel, Hand Wash Only]
# 137839             4.5            118  [Polyester,Spandex, Pull On closure]
# 528253             4.0              9                                   NaN
#
#        description  price                                             images  \
# 24011          NaN    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 426278         NaN    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 507984         NaN    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 72762          NaN    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 93351          NaN    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# ...            ...    ...                                                ...
# 137831         NaN    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 137835         NaN    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 137837         NaN    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 137839         NaN    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
# 528253         NaN    NaN  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                                    videos         store  \
# 24011                                                 NaN      BONALUNA
# 426278                                                NaN          None
# 507984                                                NaN      BONALUNA
# 72762                                                 NaN      BONALUNA
# 93351                                                 NaN      BONALUNA
# ...                                                   ...           ...
# 137831                                                NaN  Vera Bradley
# 137835                                                NaN   GRACE KARIN
# 137837  [{'title': 'Serafina Home Haunted Fleece Throw...       Hretqwi
# 137839                                                NaN      Zicotour
# 528253                                                NaN         Houda
#
#         categories                                            details  \
# 24011          NaN  {'Is Discontinued By Manufacturer': 'No', 'Pro...
# 426278         NaN  {'Is Discontinued By Manufacturer': 'No', 'Pro...
# 507984         NaN                                                 {}
# 72762          NaN  {'Product Dimensions': '2.75 x 1 x 0.5 inches;...
# 93351          NaN  {'Product Dimensions': '2.75 x 1.63 x 0.5 inch...
# ...            ...                                                ...
# 137831         NaN  {'Is Discontinued By Manufacturer': 'No', 'Pac...
# 137835         NaN  {'Package Dimensions': '13.35 x 10.16 x 1.73 i...
# 137837         NaN  {'Brand': 'Hretqwi', 'Special Feature': 'Skin ...
# 137839         NaN  {'Package Dimensions': '11.2 x 7 x 1.1 inches;...
# 528253         NaN  {'Package Dimensions': '2.76 x 2.76 x 0.79 inc...
#
#        parent_asin bought_together
# 24011   B07C5NC3NK            None
# 426278  B07C5K4QYR            None
# 507984  B07C5M7QZR            None
# 72762   B07CSLK8PD            None
# 93351   B07CSK29YH            None
# ...            ...             ...
# 137831  B07576RCQM            None
# 137835  B096VQ6B75            None
# 137837  B0B7L5YW2Q            None
# 137839  B086RC3HGL            None
# 528253  B0831H4QQZ            None
#
# [84978 rows x 14 columns]

# %%
# Parent_ASIN check
df_amazon_fashion["parent_asin"].nunique()
# Out:
# 826108

# %%
# Discontinued products count
df_amazon_fashion["is_discontinued"] = df_amazon_fashion["details"].apply(
    lambda x: x.get("Is Discontinued By Manufacturer") if isinstance(x, dict) else None
)

df_amazon_fashion["is_discontinued"].value_counts()
# Out:
# is_discontinued
# No       293405
# Yes        1838
# false       134
# False       121
# True          2
# Name: count, dtype: int64

# %%
from collections import Counter

key_counter = Counter()

for d in df_amazon_fashion["details"]:
    if isinstance(d, dict):
        key_counter.update(d.keys())

# Show the result
print(key_counter)
# Out:
# Counter({'Date First Available': 797051, 'Package Dimensions': 528478, 'Item model number': 371915, 'Is Discontinued By Manufacturer': 295500, 'Product Dimensions': 160469, 'Department': 119646, 'Manufacturer': 60671, 'Brand': 41816, 'Age Range (Description)': 23485, 'Material': 22709, 'Item Weight': 21064, 'Style': 18639, 'Color': 15047, 'Closure Type': 12144, 'Size': 8224, 'Shape': 6137, 'Reusability': 5950, 'Theme': 5864, 'Special Feature': 5690, 'Pattern': 5397, 'Country of Origin': 3834, 'Unit Count': 3726, 'Item Package Quantity': 3285, 'Clasp Type': 3216, 'Sport': 3149, 'Neck Style': 3009, 'Batteries': 2728, 'Item Dimensions LxWxH': 2689, 'Fit Type': 2569, 'Sleeve Type': 2356, 'Chain Type': 2326, 'Manufacturer recommended age': 2048, 'Number of Items': 1990, 'Number of Pieces': 1957, 'Fabric Type': 1828, 'Occasion': 1629, 'Product Care Instructions': 1609, 'Frame Material': 1582, 'Collection Name': 1532, 'Metal Type': 1266, 'Item Length': 1203, 'Shirt form type': 1158, 'Brand Name': 897, 'Metal Stamp': 892, 'Part Number': 710, 'Target Audience': 703, 'Item Package Dimensions L x W x H': 676, 'Cartoon Character': 670, 'Package Weight': 659, 'Included Components': 657, 'Collar Style': 636, 'Hand Orientation': 568, 'Item Length (Description)': 546, 'Sport Type': 525, 'Lens Color': 502, 'Form Factor': 497, 'Lining Description': 491, 'Frame Type': 480, 'Lens Coating Description': 478, 'Suggested Users': 430, 'Band Material Type': 379, 'Team Name': 371, 'Band Color': 356, 'Recommended Uses For Product': 352, 'Ply Rating': 351, 'Compatible Phone Models': 350, 'Use for': 330, 'Filter Class': 299, 'Handle Material': 291, 'Vehicle Service Type': 259, 'Opening Mechanism': 246, 'Item Form': 214, 'Manufacturer Part Number': 213, 'Number of Labels': 212, 'League': 193, 'Hair Type': 193, 'Mounting Type': 188, 'Item Dimensions  LxWxH': 187, 'Compatible Devices': 168, 'Number of Sets': 163, 'Finish Type': 160, 'Lens Material': 155, 'Stone Color': 145, 'Band Size': 142, 'Model Name': 140, 'Capacity': 128, 'Outer Material': 128, 'Material Type': 127, 'Primary Stone Gem Type': 125, '': 120, 'Band Width': 118, 'Water Resistance Level': 116, 'Language': 110, 'Size Map': 105, 'UPC': 104, 'Shaft Material': 104, 'Model Year': 102, 'Top Style': 102, 'Batteries required': 101, 'Strap Type': 100, 'Seasons': 96, 'Pocket Description': 95, 'Waist (cm)': 92, 'Screen Size': 87, 'Room Type': 84, 'Batteries Required?': 80, 'Back Style': 78, 'Closure': 75, 'Total Diamond Weight': 67, 'Orientation': 65, 'Ultraviolet Light Protection': 63, 'Number of Compartments': 63, 'Inner Material': 62, 'Power Source': 60, 'Installation Type': 57, 'Import Designation': 57, 'Target Species': 54, 'Age Range Description': 52, 'Batteries Included?': 51, 'Wallet compartment type': 49, 'Towel form type': 44, 'Other display features': 43, 'Units': 43, 'Package Information': 39, 'Fastener Type': 39, 'Gem Type': 39, 'Chain Length': 38, 'Stone Weight': 37, 'Shell Type': 36, 'Is Stain Resistant': 36, 'Fastener Material': 36, 'Special Features': 35, 'Specific Uses For Product': 35, 'Insole Type': 34, 'Compatible Material': 33, 'Lock Type': 32, 'Product Benefits': 32, 'Stone Cut': 30, 'Blade Material': 29, 'Number of Drawers': 29, 'Material Feature': 28, 'Arch Type': 27, 'Blanket Form': 27, 'Embellishment': 27, 'Connectivity Technology': 26, 'Care instructions': 26, 'Surface Recommendation': 25, 'Is Autographed': 25, 'Lifestyle': 25, 'Total Eaches': 24, 'Display Type': 23, 'Item Volume': 22, 'Light Source Type': 22, 'Connector Type': 21, 'Scent': 20, 'Breed Recommendation': 20, 'Back Material Type': 20, 'Import': 19, 'Are Batteries Included': 19, 'Domestic Shipping': 19, 'International Shipping': 19, 'Shape Irregular': 19, 'Special features': 19, 'Warranty Description': 18, 'Flavor': 18, 'Total gem weight': 18, 'Model': 18, 'Voltage': 18, 'Binding': 18, 'Controller Type': 17, 'Maximum Weight Recommendation': 17, 'Is Customizable': 17, 'Material Vinyl': 17, 'Number of pieces': 16, 'I ...

# %%
# Items price below 0.10 too cheap to be true
num_items_below_05 = df_amazon_fashion.loc[df_amazon_fashion["price"]<=0.05].shape[0]
num_items_below_10 = df_amazon_fashion.loc[df_amazon_fashion["price"]<=0.10].shape[0]

print(f"Number of items below 0.05: {num_items_below_05}")
print(f"Number of items below 0.10: {num_items_below_10}")
# Out:
# Number of items below 0.05: 56
# Number of items below 0.10: 60

# %% [markdown]
# # Observations
#
# ### Missing Value
#
# 1. There are 58 values missing in the title
# 2. There are 363034 values missing in the features
# 3. There are 766819 values missing in description
# 4. There are 775814 values missing in price
# 5. There are 1 value missing in images
# 6. There are 774001 values missing in videos
# 7. There are 26838 values missing in store
# 8. All values are missing in categories and bought_together
#
# - For semantic search, it is important to have title and description for all products.
# - We have to use input image to the llm to fill in the missing tittle.
# - Since almost all product have images, it is possible to use gpt-vision to generate description for each of the product, but we have to consider the cost to do that.
# - Fashion products can be further categorized into shoes, shirt, dress and etc using either title or the image to improve search
# - Average rating and rating number could be recalculated using either Bayesian Average Formula
# - Extracting features from the video would be too expensive.
#
# ### Product without price
#
# - About 94% of the products' price are missing, I am going to assume that the product is out of stock.
# - I would keep the product without price on the recommendation list if the detail of is_discontinue = No or False or false
# - For product without price and is_discontinue = True or Yes, the product would be dropped from recommendation because there is no chance for amazon to restock it
# - For product without price but without is_discontinue mentioned in the details, I would keep in the product list but will be lowered the importance
# - Product with price would be the first priority of recommendation, then products that are currently out of stock but will be restock will be the secondary, products that are currently out of stock but unknown about the restock will be the tertiary.
#
# ### Product without store
#
# - Assume the product without store is unavailable because there is no way customer can buy it, thus I would exclude them from the recommendation.
#
# ### Repetitive products or similar product
#
# - There are 84978 products with the same title, thus we need to arrange it by rating_number or avg_rating or price.
# - We have to look for a way to provide the best recommendation base on the avg_rating and rating_number such as Bayesian Average Rating for the top 5 most relevant product search
#
# ### Product grouping
#
# - All parent_asin values are unique, doesn't seems like the products can be grouped with this column data
#
# ### Product availability
#
# - There are 1840 products with {"Is Discontinued By Manufacturer": "Yes" / True} in their details.
# - These products might be out of stock when recommend to the customer, which we should may be drop these products.
#
# ### Product details
#
# - There are 544 different key in the details column of each product, this can be used as a useful information to help customer find specific product.
#
# ### Product with price under 0.05 dollar
#
# - These products are too cheap to be true, might be a scam for customer thus I would exclude it from the recommendation list.
